# %% [markdown]
# <h1 style="color:red">Clinical Trial Data Analysis 2021</h1>

# %% [markdown]
# ## Listing Data Directory

# %%
ls data\*.csv
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is D8CD-0B25
#
#  Directory of C:\Users\nihar\OneDrive\Desktop\Python\Data Science\Tasks\Task-5\data
#
# 26-09-2023  14:14        42,073,707 clinicaltrial_2019.csv
# 26-09-2023  08:27        50,359,696 clinicaltrial_2021.csv
# 26-09-2023  08:27         5,295,548 mesh.csv
# 26-09-2023  08:27           678,999 pharma.csv
#                4 File(s)     98,407,950 bytes
#                0 Dir(s)  766,406,246,400 bytes free

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
Data_Dir = '/data/'

# %% [markdown]
# ### Load Data

# %%
clinic_data_2021_path = os.path.join(os.getcwd()+Data_Dir, 'clinicaltrial_2021.csv')
clinic_data_2019_path = os.path.join(os.getcwd()+Data_Dir, 'clinicaltrial_2019.csv')
mesh_data_path = os.path.join(os.getcwd()+Data_Dir, 'mesh.csv')
pharma_data_path = os.path.join(os.getcwd()+Data_Dir, 'pharma.csv')

clinic_data21 = pd.read_csv(clinic_data_2021_path,sep='|')
clinic_data19 = pd.read_csv(clinic_data_2019_path,sep='|')
mesh_data = pd.read_csv(mesh_data_path)
pharma_data = pd.read_csv(pharma_data_path)

# %% [markdown]
# ###  Explore Data
#
#      Top rows of each DataFrame

# %%
clinic_data21.head()
# Out:
#             Id                                 Sponsor  \
# 0  NCT02758028             The University of Hong Kong
# 1  NCT02751957                         Duke University
# 2  NCT02758483  Universidade Federal do Rio de Janeiro
# 3  NCT02759848           Istanbul Medeniyet University
# 4  NCT02758860          University of Roma La Sapienza
#
#                    Status     Start Completion  \
# 0              Recruiting  Aug 2005   Nov 2021
# 1               Completed  Jul 2016   Jul 2020
# 2               Completed  Mar 2017   Jan 2018
# 3               Completed  Jan 2012   Dec 2014
# 4  Active, not recruiting  Jun 2016   Sep 2020
#
#                                Type Submission  \
# 0                    Interventional   Apr 2016
# 1                    Interventional   Apr 2016
# 2                    Interventional   Apr 2016
# 3                     Observational   May 2016
# 4  Observational [Patient Registry]   Apr 2016
#
#                                           Conditions Interventions
# 0                                                NaN           NaN
# 1         Autistic Disorder,Autism Spectrum Disorder           NaN
# 2                                  Diabetes Mellitus           NaN
# 3       Tuberculosis,Lung Diseases,Pulmonary Disease           NaN
# 4  Diverticular Diseases,Diverticulum,Diverticulosis           NaN

# %%
mesh_data.head()
# Out:
#          term                 tree
# 0  Calcimycin  D03.633.100.221.173
# 1     A-23187  D03.633.100.221.173
# 2     Temefos  D02.705.400.625.800
# 3     Temefos  D02.705.539.345.800
# 4     Temefos  D02.886.300.692.800

# %%
pharma_data.head()
# Out:
#                                  Company       Parent_Company  Penalty_Amount  \
# 0                    Abbott Laboratories  Abbott Laboratories      $5,475,000
# 1               Abbott Laboratories Inc.               AbbVie  $1,500,000,000
# 2               Abbott Laboratories Inc.               AbbVie    $126,500,000
# 3  Abbott Laboratories Puerto Rico, Inc.  Abbott Laboratories         $49,045
# 4                         Acclarent Inc.    Johnson & Johnson     $18,000,000
#
#   Subtraction_From_Penalty  \
# 0                       $0
# 1                       $0
# 2                       $0
# 3                       $0
# 4                       $0
#
#   Penalty_Amount_Adjusted_For_Eliminating_Multiple_Counting  Penalty_Year  \
# 0                                         $5,475,000                 2013
# 1                                     $1,500,000,000                 2012
# 2                                       $126,500,000                 2010
# 3                                            $49,045                 2009
# 4                                        $18,000,000                 2016
#
#    Penalty_Date                            Offense_Group  \
# 0      20131227  government-contracting-related offenses
# 1      20120507              healthcare-related offenses
# 2      20101207  government-contracting-related offenses
# 3      20090305              employment-related offenses
# 4      20160722  government-contracting-related offenses
#
#                                      Primary_Offense  \
# 0                       False Claims Act and related
# 1  off-label or unapproved promotion of medical p...
# 2                       False Claims Act and related
# 3                            wage and hour violation
# 4                       False Claims Act and related
#
#           Secondary_Offense  \
# 0     kickbacks and bribery
# 1                       NaN
# 2                       NaN
# 3  Fair Labor Standards Act
# 4                       NaN
#
#                                          Description Level_of_Government  \
# 0  Abbott Laboratories agreed to $5.475 million t...             federal
# 1  Global Health Care Company Abbott Laboratories...             federal
# 2  Abbott Laboratories Inc., B. Braun Medical Inc...             federal
# 3                                                NaN             federal
# 4  California-based medical device manufacturer A...             federal
#
#      Action_Type                                             Agency  \
# 0  agency action                  Justice Department Civil Division
# 1  agency action  Food and Drug Administration referral to the J...
# 2  agency action                  Justice Department Civil Division
# 3  agency action            Labor Department Wage and Hour Division
# 4  agency action                  Justice Department Civil Division
#
#        Civil/Criminal Prosecution_Agreement Court  Case_ID  \
# 0               civil                   NaN   NaN      NaN
# 1  civil and criminal                   NaN   NaN      NaN
# 2               civil                   NaN   NaN      NaN
# 3               civil                   NaN   NaN  1527129
# 4               civil                   NaN   NaN      NaN
#
#   Private_Litigation_Case_Title Lawsuit_Resolution Facility_State      City  \
# 0                           NaN                NaN            NaN       NaN
# 1                           NaN                NaN            NaN       NaN
# 2                           NaN                NaN            NaN       NaN
# 3                           NaN                NaN    Puerto Rico  San Juan
# 4                           NaN                NaN            NaN       NaN
#
#   Address  Zip  NAICS_Code                                  NAICS_Translation  \
# 0     NaN  NaN         NaN                                                NaN
# 1     NaN  NaN         NaN                                                NaN
# 2     NaN  NaN         NaN                                                NaN
# 3     NaN  NaN    423450.0  423450: Medical, Dental, and Hospital Equipmen...
# 4     NaN  NaN         NaN                                                NaN
#
#   HQ_Country_of_Parent HQ_State_of_Parent Ownership_Structure  \
# 0                  USA           Illinois     publicly traded
# 1                  USA           Illinois     publicly traded
# 2                  USA           Illinois     publicly traded
# 3                  USA           Illinois     publicly traded
# 4                  USA         New Jersey     publicly traded
#
#   Parent_Company_Stock_Ticker Major_Industry_of_Parent  \
# 0                         ABT          pharmaceuticals
# 1                        ABBV          pharmaceuticals
# 2                        ABBV          pharmaceuticals
# 3                         ABT          pharmaceuticals
# 4                         JNJ          pharmaceuticals
#
#   Specific_Industry_of_Parent  \
# 0             pharmaceuticals
# 1             pharmaceuticals
# 2             pharmaceuticals
# 3             pharmaceuticals
# 4             pharmaceuticals
#
#                                          Info_Source  \
# 0  https://www.justice.gov/opa/pr/abbott-laborato...
# 1  http://www.justice.gov/opa/pr/abbott-labs-pay-...
# 2  https://www.justice.gov/opa/pr/pharmaceutical-...
# 3  March 7, 2017 download of a dataset posted by ...
# 4  https://www.justice.gov/opa/pr/johnson-johnson...
#
#                                                Notes
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Date and year are the Findings End Date in the...
# 4                                                NaN

# %%
## Null Values per column
clinic_data21.isna().sum()
# Out:
# Id                    0
# Sponsor               0
# Status                0
# Start                 0
# Completion        13260
# Type                  0
# Submission            0
# Conditions        65131
# Interventions    253837
# dtype: int64

# %%
#Null Values in Percentage
round((clinic_data21.isna().sum()/clinic_data21.shape[0])*100, 2)
# Out:
# Id                0.00
# Sponsor           0.00
# Status            0.00
# Start             0.00
# Completion        3.42
# Type              0.00
# Submission        0.00
# Conditions       16.82
# Interventions    65.55
# dtype: float64

# %% [markdown]
# ### Outline
#
#     We will follow a typical data analysis process
#
#     1. Load / ingest the data to be analysed
#     2. Prepare / clean the data
#     3. Analyse the data
#     4. Visualise results / generate report

# %% [markdown]
# ### Data Description
#
#     1. clinicaltrial <year>.csv: each row represents an individual clinical trial, identified by an Id,
#         listing the sponsor (Sponsor), the status of the study at time of the file’s download (Status), the
#         start and completion dates (Start and Completion respectively), the type of study (Type), when the
#         trial was first submitted (Submission), and the lists of conditions the trial concerns (Conditions) and
#         the interventions explored (Interventions). Individual conditions and interventions are separated by
#         commas. (Source: ClinicalTrials.gov)
#
#
#     2. mesh.csv: the conditions from the clinical trial list may also appear in a number of hierarchies. The
#         hierarchy identifiers have the format [A-Z][0-9]+(˙
#         [A-Z][0-9]+)* (such as, e.g., D03.633.100.221.173)
#         where the initial letter and number combination designates the root of this particular hierarchy
#         (in the example, this is D03) and each “.” descends a level down the hierarchy. The rows of this
#         file contain condition (term), hierarchy identifier (tree) pairs. (Source: U.S. National Library of
#         Medicine.)
#
#     3. pharma.csv: the file contains a small number of a publicly available list of pharmaceutical violations.
#         For the puposes of this work, we are interested in the second column, Parent Company, which contains the name of the pharmaceutical company in question. (Source: https://violationtracker.
#     goodjobsfirst.org/industry/pharmaceuticals)

# %% [markdown]
# ### Problem statements
#
#
#     You are a data analyst / data scientist whose client wishes to gain further insight into clinical trials. You
#     are tasked with answering these questions, using visualisations where these would support your conclusions.
#     You should address the following problem statements. You should use the solutions for historical datasets
#     (available on Blackboard) to test your implementation.
#
#
#     1. The number of studies in the dataset. You must ensure that you explicitly check distinct studies.
#
#     2. You should list all the types (as contained in the Type column) of studies in the dataset along with
#         the frequencies of each type. These should be ordered from most frequent to least frequent.
#
#     3. The top 5 conditions (from Conditions) with their frequencies.
#
#     4. Each condition can be mapped to one or more hierarchy codes. The client wishes to know the 5
#         most frequent roots (i.e. the sequence of letters and numbers before the first full stop) after this is done.
#
#                 To clarify, suppose your clinical trial data was:
#
#                     NCT01, ... ,"Disease_A,Disease_B",
#                     NCT02, ... ,Disease_B,
#
#                 And the mesh file contained:
#
#                     Disease_A A01.01 C23.02
#                     Disease_B B01.34.56
#
#                 The result would be
#
#                     B01 2
#                     A01 1
#                     C23 1
#     5. Find the 10 most common sponsors that are not pharmaceutical companies, along with the number
#         of clinical trials they have sponsored. Hint: For a basic implementation, you can assume that the
#         Parent Company column contains all possible pharmaceutical companies.
#
#     6. Plot number of completed studies each month in a given year – for the submission dataset, the year
#         is 2021. You need to include your visualization as well as a table of all the values you have plotted
#         for each month

# %%
nrows = clinic_data21.shape[0]
print(f"We have total {nrows} clinical trials.")
# Out:
# We have total 387261 clinical trials.

# %% [markdown]
# ### 1. The number of studies in the dataset

# %%
clinic_data21['Id'].unique().shape[0]
# Out:
# 387261

# %%
total_studies = clinic_data21['Id'].nunique()
print(f" We have total {total_studies} cases in Clinical Trial 2021 Datasets." )
# Out:
#  We have total 387261 cases in Clinical Trial 2021 Datasets.

# %% [markdown]
# ### 2. Listing all the types (as contained in the Type column) of studies in the dataset along with the frequencies of each type
#
#     Ordered from most frequent to least frequent.

# %%
clinic_data21.groupby('Type')['Id'].count().sort_values(ascending=False)
# Out:
# Type
# Interventional                      301472
# Observational                        77540
# Observational [Patient Registry]      8180
# Expanded Access                         69
# Name: Id, dtype: int64

# %%
study_type = clinic_data21.groupby('Type')['Id'].count().sort_values(ascending=False).reset_index()
study_type.columns = ['Type','Count']

# %%
study_type
# Out:
#                                Type   Count
# 0                    Interventional  301472
# 1                     Observational   77540
# 2  Observational [Patient Registry]    8180
# 3                   Expanded Access      69

# %%
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['figure.dpi'] =200
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10

# %%
plt.figure()
sns.barplot(x = 'Count',y = 'Type',data=study_type,
           palette='YlOrBr', orient='h')
ax = plt.gca()
plt.grid(alpha=0.2)
for patch, lb in zip(ax.patches, ax.get_yticklabels()):
    x = patch.get_y()+0.5
    h = patch = patch.get_width()
    y = h
    text = int(h)
    
    ax.text(y, x, text, fontsize=20, color='red')
    lb.set_color('red')
plt.title('Type Of Study',color='red',pad =20, fontsize=20)
plt.ylabel('Frequency',color='red',fontsize=20)
plt.xlabel('Count',color='red',fontsize=20)
plt.xticks(color='red')
plt.gca().spines[['right','top']].set_visible(False)

# %%
plt.pie(x=study_type['Count'], labels = study_type['Type'],
       autopct='%.2f%%',pctdistance=0.75, explode=[0,0,0.3,0])
plt.grid(alpha=0.2)
crc = plt.Circle((0,0), 0.5, color='white')
plt.gca().add_artist(crc)
plt.title('Type Of Studies', color='red', fontsize=20, pad = 10)
plt.ylabel('Frequency', color='red', fontsize=20)
plt.show()

# %% [markdown]
# ### 3. The top 5 conditions (from Conditions) with their frequencies.

# %% [markdown]
# ##### Preprocessing Data

# %%
cond = clinic_data21['Conditions'].str.split(',')
all_cond = [con for con in cond.values if con is not np.nan]
cond = pd.Series(all_cond)
cond[:10]
# Out:
# 0        [Autistic Disorder, Autism Spectrum Disorder]
# 1                                  [Diabetes Mellitus]
# 2     [Tuberculosis, Lung Diseases, Pulmonary Disease]
# 3    [Diverticular Diseases, Diverticulum, Divertic...
# 4                                             [Asthma]
# 5                                    [Hypoventilation]
# 6                                           [Lymphoma]
# 7                                           [Myositis]
# 8                                  [Diabetes Mellitus]
# 9                                       [Hypertension]
# dtype: object

# %%
top_cond = cond.value_counts().head(10).reset_index()

# %%
top_cond.columns = ['Condition','Frequency']

# %%
s = pd.Series(all_cond)

# %%
s.value_counts().head()
# Out:
# [Diabetes Mellitus]      7460
# [Breast Neoplasms]       6054
# [Carcinoma]              3788
# [Prostatic Neoplasms]    3700
# [COVID-19]               3118
# dtype: int64

# %%
top_cond
# Out:
#                      Condition  Frequency
# 0          [Diabetes Mellitus]       7460
# 1           [Breast Neoplasms]       6054
# 2                  [Carcinoma]       3788
# 3        [Prostatic Neoplasms]       3700
# 4                   [COVID-19]       3118
# 5             [Osteoarthritis]       3076
# 6                  [Neoplasms]       2899
# 7                   [Lymphoma]       2838
# 8              [Heart Failure]       2534
# 9  [Lung Neoplasms, Carcinoma]       2482

# %%
plt.pie('Frequency', labels = 'Condition',
       data = top_cond, autopct='%.2f%%',
       pctdistance = 0.75)
plt.grid(alpha=0.2)
crc = plt.Circle((0,0), 0.5, color='white')
plt.gca().add_artist(crc)
plt.title('Top Clinical Conditions', color='red', pad = 10, fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top Clinical Conditions')

# %% [markdown]
# ### 4. Each condition can be mapped to one or more hierarchy codes. The client wishes to know the 5
#
#         most frequent roots (i.e. the sequence of letters and numbers before the first full stop) after this is done.
#
#             To clarify, suppose your clinical trial data was:
#
#                 NCT01, ... ,"Disease_A,Disease_B",
#                 NCT02, ... ,Disease_B,
#
#             And the mesh file contained:
#
#                 Disease_A A01.01 C23.02
#                 Disease_B B01.34.56
#
#             The result would be
#
#                 B01 2
#                 A01 1
#                 C23 1

# %%
# Extracting Mesh Code From Mesh Tree
mesh_data['code'] = mesh_data['tree'].str.split('.', expand=True)[0]

# %%
mesh_code = mesh_data[['term','code']]
mesh_code.head()
# Out:
#          term code
# 0  Calcimycin  D03
# 1     A-23187  D03
# 2     Temefos  D02
# 3     Temefos  D02
# 4     Temefos  D02

# %%
mesh_code.set_index('term',inplace=True)

# %%
mesh_code.head()
# Out:
#            code
# term
# Calcimycin  D03
# A-23187     D03
# Temefos     D02
# Temefos     D02
# Temefos     D02

# %%
trial_cond = cond.reset_index().drop('index',axis=1).copy()
trial_cond.columns = ['condition']

# %%
trial_cond.head()
# Out:
#                                            condition
# 0      [Autistic Disorder, Autism Spectrum Disorder]
# 1                                [Diabetes Mellitus]
# 2   [Tuberculosis, Lung Diseases, Pulmonary Disease]
# 3  [Diverticular Diseases, Diverticulum, Divertic...
# 4                                           [Asthma]

# %%
mesh_code.reset_index(inplace=True)
mesh_code.columns = ['condition','code']

# %%
mesh_code[:10]
# Out:
#     condition code
# 0  Calcimycin  D03
# 1     A-23187  D03
# 2     Temefos  D02
# 3     Temefos  D02
# 4     Temefos  D02
# 5       Abate  D02
# 6       Abate  D02
# 7       Abate  D02
# 8       Difos  D02
# 9       Difos  D02

# %%
codes = mesh_code.merge(trial_cond,on='condition')
codes = codes.groupby('code').count()
codes = codes.sort_values('condition',ascending=False).reset_index()
codes.column = ['code','count']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 codes = mesh_code.merge(trial_cond,on='condition')
#       2 codes = codes.groupby('code').count()
#       3 codes = codes.sort_values('condition',ascending=False).reset_index()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
#   10104         copy=copy,
#   10105         indicator=indicator,
#   10106         validate=validate,
#   10107     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:124, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
#     110     op = _MergeOperation(
#     111         left,
#     112         right,
#    (...)
#     122         validate=validate,
#     123     )
# --> 124     return op.get_result(copy=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:773, in _MergeOperation.get_result(self, copy)
#     770 if self.indicator:
#     771     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 773 join_index, left_indexer, right_indexer = self._get_join_info()
#     775 result = self._reindex_and_concat(
#     776     join_index, left_indexer, right_indexer, copy=copy
#     777 )
#     778 result = result.__finalize__(self, method=self._merge_type)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1026, in _MergeOperation._get_join_info(self)
#    1022     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1023         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1024     )
#    1025 else:
# -> 1026     (left_indexer, right_indexer) = self._get_join_indexers()
#    1028     if self.right_index:
#    1029         if len(self.left) > 0:
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1000, in _MergeOperation._get_join_indexers(self)
#     998 def _get_join_indexers(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#     999     """return the join indexers"""
# -> 1000     return get_join_indexers(
#    1001         self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1002     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1585, in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1580 # get left & right join labels and num. of levels at each location
#    1581 mapped = (
#    1582     _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)
#    1583     for n in range(len(left_keys))
#    1584 )
# -> 1585 zipped = zip(*mapped)
#    1586 llab, rlab, shape = (list(x) for x in zipped)
#    1588 # get flat i8 keys from label lists
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1582, in <genexpr>(.0)
#    1578         return _get_no_sort_one_missing_indexer(left_n, False)
#    1580 # get left & right join labels and num. of levels at each location
#    1581 mapped = (
# -> 1582     _factorize_keys(left_keys[n], right_keys[n], sort=sort, how=how)
#    1583     for n in range(len(left_keys))
#    1584 )
#    1585 zipped = zip(*mapped)
#    1586 llab, rlab, shape = (list(x) for x in zipped)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:2333, in _factorize_keys(lk, rk, sort, how)
#    2329 llab = rizer.factorize(lk)  # type: ignore[arg-type]
#    2330 # Argument 1 to "factorize" of "ObjectFactorizer" has incompatible type
#    2331 # "Union[ndarray[Any, dtype[signedinteger[_64Bit]]],
#    2332 # ndarray[Any, dtype[object_]]]"; expected "ndarray[Any, dtype[object_]]"
# -> 2333 rlab = rizer.factorize(rk)  # type: ignore[arg-type]
#    2334 assert llab.dtype == np.dtype(np.intp), llab.dtype
#    2335 assert rlab.dtype == np.dtype(np.intp), rlab.dtype
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\hashtable.pyx:125, in pandas._libs.hashtable.ObjectFactorizer.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:5951, in pandas._libs.hashtable.PyObjectHashTable.get_labels()
#
# File pandas\_libs\hashtable_class_helper.pxi:5857, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
